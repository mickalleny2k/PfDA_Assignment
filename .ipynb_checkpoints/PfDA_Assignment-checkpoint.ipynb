# %% [markdown]
# # Programming for Data Analysis Assignment

# %%
import numpy as np
import pandas as pd

# https://www.pgatour.com/stats/detail/120
df = pd.read_csv('pgatour_golfstats_2022-2023_averagescore.csv')
df
# Out:
#      RANK  MOVEMENT  PLAYER_ID             PLAYER     AVG  TOTAL STROKES  \
# 0       1         0      46046  Scottie Scheffler  68.629           6007
# 1       2         0      28237       Rory McIlroy  68.777           4411
# 2       3         0      46970           Jon Rahm  69.037           4886
# 3       4         0      46717     Viktor Hovland  69.123           6065
# 4       5         0      48081  Xander Schauffele  69.127           5595
# ..    ...       ...        ...                ...     ...            ...
# 184   185        -2      51950       Max McGreevy  72.603           6170
# 185   186        -2      28420         Ryan Brehm  72.739           5740
# 186   187        -2      32662     Michael Gligic  72.775           4953
# 187   188        -2      27095        Nick Watney  72.936           5052
# 188   189        -2      51491   Brandon Matthews  73.153           4262
#
#      TOTAL ADJUSTMENT  TOTAL ROUNDS
# 0              32.329            88
# 1              -9.244            64
# 2              15.615            71
# 3              17.843            88
# 4               4.323            81
# ..                ...           ...
# 184            73.869            86
# 185            79.134            80
# 186            68.445            69
# 187            53.529            70
# 188            54.054            59
#
# [189 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
x = df.AVG
plt.plot(df.AVG)
plt.show()

# %%
# Plot Average Score data from pgatour_golfstats_2022-2023_averagescore.csv
plt.hist(x, bins=10)
plt.show()

# %%
df.AVG
# Out:
# 0      68.629
# 1      68.777
# 2      69.037
# 3      69.123
# 4      69.127
#         ...
# 184    72.603
# 185    72.739
# 186    72.775
# 187    72.936
# 188    73.153
# Name: AVG, Length: 189, dtype: float64

# %%
std = df.AVG.std()
std
# Out:
# 0.8301339718593281

# %%
mean = df.AVG.mean()
mean
# Out:
# 70.96867724867725

# %%
df.describe()
# Out:
#              RANK    MOVEMENT     PLAYER_ID         AVG  TOTAL STROKES  \
# count  189.000000  189.000000    189.000000  189.000000     189.000000
# mean    94.957672   -0.449735  39114.994709   70.968677    5977.037037
# std     54.705579    3.487647  10294.967774    0.830134    1123.886273
# min      1.000000  -13.000000  12716.000000   68.629000    3198.000000
# 25%     48.000000   -2.000000  31560.000000   70.461000    5217.000000
# 50%     94.000000    0.000000  36699.000000   70.966000    6065.000000
# 75%    142.000000    2.000000  48117.000000   71.524000    6799.000000
# max    189.000000   19.000000  59018.000000   73.153000    8450.000000
#
#        TOTAL ADJUSTMENT  TOTAL ROUNDS
# count        189.000000    189.000000
# mean          53.245196     85.026455
# std           26.348952     16.241670
# min          -18.811000     45.000000
# 25%           35.723000     74.000000
# 50%           55.784000     86.000000
# 75%           73.356000     96.000000
# max          106.517000    122.000000

# %%
count = df.count()
count
# Out:
# RANK                189
# MOVEMENT            189
# PLAYER_ID           189
# PLAYER              189
# AVG                 189
# TOTAL STROKES       189
# TOTAL ADJUSTMENT    189
# TOTAL ROUNDS        189
# dtype: int64

# %%
# Synthesize a random normal distribution for Average Score
# I choose mu of 70.96 because this is the average score in pgatour_golfstats_2022-2023_averagescore.csv
y = np.random.normal(mean,std,189)
y
# Out:
# array([71.1515058 , 70.66195599, 71.70223456, 70.85827346, 71.44028483,
#        71.11090451, 69.52813752, 70.9521326 , 69.48069982, 71.25406219,
#        71.21616017, 69.87709187, 71.83350928, 69.70697233, 69.94791653,
#        70.8892325 , 70.54253394, 72.60911938, 71.72995382, 71.17488704,
#        70.30322814, 69.48020049, 71.70059734, 71.40173221, 69.7500886 ,
#        71.48354381, 70.68895381, 70.04991606, 70.67795957, 70.88249163,
#        71.79307182, 71.16494214, 70.55373365, 71.82689698, 70.47046474,
#        71.56626396, 71.62198846, 71.16608716, 70.61980658, 70.83955768,
#        71.80540065, 70.14966243, 70.83450729, 70.81611593, 70.57495146,
#        70.07620356, 70.60948551, 71.13424699, 71.32609991, 71.32919211,
#        70.17946528, 69.98578591, 70.35298042, 70.86547464, 71.60834818,
#        71.88733349, 71.1673775 , 70.28544797, 71.81889622, 71.85849989,
#        70.55388562, 69.09052341, 71.0671318 , 71.20781022, 71.13528378,
#        71.17565306, 71.19412603, 72.19770333, 72.10304307, 70.95115421,
#        71.35303018, 70.41697358, 70.44210479, 69.50417503, 70.88030249,
#        72.41473011, 70.37261663, 70.19976478, 71.97053077, 72.85941285,
#        70.93586807, 71.25671149, 70.86981154, 72.64124696, 70.83802516,
#        70.85095388, 71.85676562, 71.08203107, 69.28587314, 70.96106735,
#        72.27986459, 71.95651083, 70.44479268, 70.32521492, 71.31854052,
#        71.25564123, 71.56961   , 71.0030927 , 72.20300754, 71.06123592,
#        70.09531465, 70.43798773, 69.71777633, 70.54653424, 71.9983121 ,
#        70.99728588, 71.36137663, 71.59011252, 73.13314844, 70.31920628,
#        71.4015046 , 71.32552345, 71.4937412 , 71.57526135, 70.7476041 ,
#        70.90447488, 69.23890231, 71.03925707, 70.07968532, 70.43586646,
#        71.47921668, 71.12459405, 71.28135776, 69.77334179, 70.15663772,
#        71.18381548, 72.56117312, 72.81031872, 71.19113381, 71.76267768,
#        71.1459387 , 70.97381941, 71.33077367, 71.14166355, 70.88298014,
#        71.00997339, 72.18439109, 71.14872917, 71.9128825 , 72.38058209,
#        70.69629597, 72.18632489, 70.08106411, 70.82853503, 71.96421122,
#        70.84452023, 70.49094617, 71.81265858, 71.87667318, 70.7007234 ,
#        71.70808016, 71.61225941, 70.46129405, 71.15977793, 70.79149595,
#        70.24512876, 70.20215555, 70.80486839, 72.29375026, 71.83920366,
#        70.20819727, 70.95066018, 72.25846027, 71.44040601, 71.64658155,
#        71.87152108, 70.78303649, 70.70613747, 70.65421139, 70.51743979,
#        69.92753103, 71.27715088, 71.18401089, 71.73719167, 70.51647243,
#        71.50570245, 71.34740467, 70.52893924, 70.65549227, 70.30805274,
#        69.73509131, 71.43520595, 71.20389379, 72.54610653, 71.25972189,
#        70.35199531, 70.74765311, 72.06408964, 72.03479596])

# %%
# Plot random normal distribution for Average Score
plt.hist(y)
plt.show()

# %%
# Synthesize a poisson distribution for Average Score
p = np.random.default_rng().poisson(mean, 189)
p
# Out:
# array([67, 81, 85, 68, 63, 70, 69, 72, 58, 77, 68, 72, 76, 71, 75, 67, 77,
#        78, 66, 67, 58, 76, 60, 63, 56, 59, 72, 70, 83, 64, 79, 73, 70, 69,
#        84, 97, 71, 74, 76, 73, 75, 67, 73, 53, 71, 64, 70, 64, 61, 78, 62,
#        53, 63, 75, 84, 71, 71, 59, 74, 77, 77, 74, 72, 85, 79, 78, 78, 71,
#        80, 74, 82, 73, 81, 68, 78, 62, 67, 64, 79, 81, 66, 55, 74, 66, 70,
#        74, 63, 75, 59, 64, 81, 72, 61, 67, 77, 63, 84, 63, 69, 83, 67, 63,
#        71, 70, 78, 72, 64, 73, 78, 62, 68, 75, 73, 82, 76, 63, 72, 73, 87,
#        76, 64, 85, 76, 85, 75, 81, 72, 52, 67, 71, 73, 73, 81, 78, 68, 74,
#        87, 78, 71, 67, 74, 94, 73, 73, 58, 75, 78, 71, 71, 68, 69, 72, 70,
#        61, 77, 83, 54, 75, 67, 73, 75, 78, 62, 82, 62, 66, 67, 73, 65, 71,
#        67, 75, 88, 64, 68, 66, 77, 75, 64, 73, 78, 66, 47, 78, 67, 72, 59,
#        68, 78], dtype=int64)

# %%
# Plot poisson distribution for Average Score
plt.hist(p)
plt.show()

# %%
# https://www.pgatour.com/stats/detail/101
df1 = pd.read_csv('pgatour_golfstats_2022-2023_driving.csv')
df1
# Out:
#      RANK  MOVEMENT  PLAYER_ID            PLAYER    AVG  TOTAL DISTANCE  \
# 0       1         0      28237      Rory McIlroy  326.3           41771
# 1       2         0      51491  Brandon Matthews  321.3           37915
# 2       3         0      52372     Cameron Champ  318.8           47180
# 3       4         0      52453  Nicolai Hojgaard  317.7           29227
# 4       5         0      57366     Cameron Young  316.5           51902
# ..    ...       ...        ...               ...    ...             ...
# 184   185        -2      30927      Brendon Todd  282.8           54300
# 185   186        -2      40058         Zac Blair  282.4           42920
# 186   187        -2      31202    William McGirt  281.0           25292
# 187   188        -2      34409   David Lingmerth  279.2           45789
# 188   189        -2      31560      Brian Stuard  272.5           36510
#
#      TOTAL DRIVES
# 0             128
# 1             118
# 2             148
# 3              92
# 4             164
# ..            ...
# 184           192
# 185           152
# 186            90
# 187           164
# 188           134
#
# [189 rows x 7 columns]

# %%
x = df1.RANK
y = df1.AVG
plt.plot(x,y)
plt.show()

# %%
# Plot Driving Distance data from pgatour_golfstats_2022-2023_driving.csv
plt.hist(y, bins=10)
plt.show()

# %%
df1.AVG
# Out:
# 0      326.3
# 1      321.3
# 2      318.8
# 3      317.7
# 4      316.5
#        ...
# 184    282.8
# 185    282.4
# 186    281.0
# 187    279.2
# 188    272.5
# Name: AVG, Length: 189, dtype: float64

# %%
std = df1.AVG.std()
std
# Out:
# 8.66203975287581

# %%
mean = df1.AVG.mean()
mean
# Out:
# 300.96402116402106

# %%
df1.describe()
# Out:
#              RANK    MOVEMENT     PLAYER_ID         AVG  TOTAL DISTANCE  \
# count  189.000000  189.000000    189.000000  189.000000      189.000000
# mean    94.719577   -0.904762  39114.994709  300.964021    51175.285714
# std     54.711144    1.968212  10294.967774    8.662040     9840.011169
# min      1.000000   -5.000000  12716.000000  272.500000    25292.000000
# 25%     48.000000   -2.000000  31560.000000  295.200000    44589.000000
# 50%     94.000000   -1.000000  36699.000000  300.800000    51338.000000
# 75%    142.000000    0.000000  48117.000000  306.400000    57791.000000
# max    189.000000    7.000000  59018.000000  326.300000    72978.000000
#
#        TOTAL DRIVES
# count     189.00000
# mean      170.05291
# std        32.48334
# min        90.00000
# 25%       148.00000
# 50%       172.00000
# 75%       192.00000
# max       244.00000

# %%
count = df1.count()
count
# Out:
# RANK              189
# MOVEMENT          189
# PLAYER_ID         189
# PLAYER            189
# AVG               189
# TOTAL DISTANCE    189
# TOTAL DRIVES      189
# dtype: int64

# %%
# Synthesize a random normal distribution for Driving Distance
# I choose mu of 300.5 because this is the average drivage distance in pgatour_golfstats_2022-2023_driving.csv
mu, sigma = 300.96, 8.66 # mean and standard deviation
s = np.random.default_rng().normal(mu, sigma, 189)
s
# Out:
# array([319.37506637, 293.0589997 , 325.70164733, 284.2585307 ,
#        300.25576663, 304.59764756, 288.83975569, 298.47844033,
#        305.21414021, 296.1175246 , 298.63166562, 307.67044271,
#        291.54246033, 286.49461309, 302.00467075, 298.88861609,
#        290.14309365, 306.37326553, 313.8952303 , 302.93752022,
#        310.33077766, 303.82938267, 302.35296316, 294.21761542,
#        301.93445724, 296.76992907, 298.46732336, 309.84451723,
#        307.36014708, 290.15112617, 306.37572858, 281.86918916,
#        304.16628782, 320.17122997, 297.6734913 , 305.69704596,
#        300.34377884, 308.25761721, 284.18138545, 312.80676238,
#        305.74966474, 308.98136917, 294.57940936, 293.2509901 ,
#        303.7917563 , 310.27550849, 290.3703561 , 305.28647862,
#        310.04190063, 303.84275888, 304.47706137, 304.07574754,
#        297.25355797, 312.40630621, 308.00130767, 317.16206736,
#        289.64068671, 310.24913519, 294.72321865, 301.45145575,
#        310.82052078, 283.64833893, 299.42121544, 304.98391634,
#        296.50448718, 306.21560369, 304.38181547, 284.09972886,
#        288.84521077, 297.67413243, 295.11783274, 308.34800816,
#        294.70977676, 286.39323476, 285.36643607, 296.23328565,
#        299.32584233, 312.62752074, 297.42261081, 309.50534385,
#        304.98567574, 299.94747731, 302.14835666, 292.37953005,
#        300.29441   , 289.66442211, 324.84780211, 287.87537232,
#        298.2048724 , 299.60829154, 299.57078396, 302.39904405,
#        294.37039475, 315.05707895, 294.79765024, 313.48849431,
#        295.82538427, 301.71618122, 287.01690629, 301.50088597,
#        300.61573615, 292.87554504, 315.99506159, 300.94192746,
#        303.71722671, 295.76992204, 300.93634149, 299.31653446,
#        304.88385738, 299.04130684, 294.71511159, 294.30483371,
#        295.63168814, 303.64220765, 310.32786034, 312.79763079,
#        288.17794866, 309.27490728, 287.82967918, 296.14061797,
#        297.34657193, 312.4947621 , 291.95142191, 300.29728712,
#        301.20976509, 298.55328944, 294.11324698, 301.60260082,
#        298.4993136 , 282.35799251, 298.99289937, 294.9135844 ,
#        290.76705027, 294.43856317, 305.98786598, 314.00972608,
#        308.47408606, 303.6650727 , 292.54100341, 302.26834011,
#        301.43693504, 295.18736646, 300.78930142, 299.84077791,
#        302.36321048, 314.61095699, 299.82778071, 294.70983283,
#        311.69010348, 309.20315897, 310.96884115, 295.2920115 ,
#        300.32326212, 297.37942317, 294.00644302, 298.64029336,
#        306.33849921, 290.43585076, 309.62638703, 303.00503164,
#        295.26235825, 308.60124681, 294.36670688, 293.12205133,
#        301.49701342, 287.59845174, 306.74426506, 296.65867445,
#        285.46398754, 298.77513796, 314.93686132, 304.82246755,
#        304.46737457, 301.6458551 , 319.24102112, 301.28048142,
#        290.45063605, 317.85264305, 289.06653115, 311.82573156,
#        311.85317094, 295.77453071, 298.28017915, 300.76366015,
#        301.37764214, 298.43842959, 291.70430357, 291.03851815,
#        296.9917756 ])

# %%
# Plot random normal distribution for Driving Distance
plt.hist(s)
plt.show()

# %%
# Synthesize a poisson distribution for Driving Distance
p = np.random.default_rng().poisson(mu,189)
p
# Out:
# array([309, 299, 289, 326, 314, 290, 294, 302, 274, 306, 291, 325, 307,
#        300, 308, 314, 311, 301, 309, 314, 290, 308, 274, 301, 274, 337,
#        303, 296, 276, 300, 301, 314, 298, 309, 307, 311, 290, 292, 309,
#        278, 302, 289, 330, 290, 299, 346, 314, 283, 340, 327, 312, 309,
#        320, 324, 282, 281, 298, 323, 303, 313, 306, 302, 305, 302, 291,
#        278, 314, 293, 301, 321, 303, 303, 283, 287, 302, 298, 279, 308,
#        288, 297, 289, 317, 291, 285, 297, 304, 285, 314, 315, 304, 308,
#        298, 284, 282, 273, 275, 303, 293, 309, 282, 318, 295, 308, 323,
#        302, 288, 267, 273, 300, 276, 315, 300, 288, 291, 278, 291, 312,
#        294, 299, 316, 260, 306, 286, 341, 310, 309, 304, 311, 275, 293,
#        300, 294, 337, 292, 284, 316, 297, 301, 284, 298, 309, 297, 315,
#        270, 262, 295, 311, 299, 308, 289, 311, 275, 304, 310, 308, 307,
#        303, 313, 300, 319, 314, 284, 295, 305, 299, 328, 292, 315, 275,
#        316, 272, 303, 315, 295, 291, 297, 319, 305, 298, 306, 251, 319,
#        278, 292, 296, 278, 292, 286, 347], dtype=int64)

# %%
# Plot poisson distribution for Driving Distance
plt.hist(p)
plt.show()

# %%
dataframe1 = pd.read_excel('dpworldtour_2022-2023_scoringaverage.xlsx')
dataframe1
# Out:
#        1  Unnamed: 1      MCILROY, Rory  30   68.8  DP World Tour
# 0      2         NaN   BJÖRK, Alexander  88  69.53  DP World Tour
# 1      3         NaN  HØJGAARD, Nicolai  61  69.59  DP World Tour
# 2      4         NaN     KIMSEY, Nathan  76  69.74  DP World Tour
# 3      5         NaN  OLESEN, Thorbjørn  84  69.80  DP World Tour
# 4      6         NaN     MERONK, Adrian  77  69.81  DP World Tour
# ..   ...         ...                ...  ..    ...            ...
# 168  170         NaN       MURPHY, John  51  73.86  DP World Tour
# 169  171         NaN        LI, Haotong  43  74.07  DP World Tour
# 170  172         NaN     WINDRED, Blake  34  74.18  DP World Tour
# 171  173         NaN       CHENGYAO, Ma  40  74.83  DP World Tour
# 172  174         NaN       EDÉN, Tobias  41  75.07  DP World Tour
#
# [173 rows x 6 columns]

# %%
dataframe2 = pd.read_excel('Shane Lowry_2022-2-23_Results_time-series.xlsx')
dataframe2
# Out:
#           DATE                                         TOURNAMENT  POS  R1  \
# 0   10.23.2022                       THE CJ CUP in South Carolina  T23  68
# 1    12.4.2022                              Hero World Challenge*   18  74
# 2    2.12.2023                                    WM Phoenix Open  CUT  75
# 3    2.19.2023                           The Genesis Invitational  T14  69
# 4    2.26.2023                                  The Honda Classic   T5  68
# 5     3.5.2023  Arnold Palmer Invitational presented by Master...   67  72
# 6    3.12.2023                           THE PLAYERS Championship  T35  77
# 7    3.26.2023  World Golf Championships-Dell Technologies Mat...  T31   -
# 8     4.9.2023                                 Masters Tournament  T16  68
# 9    4.16.2023                                       RBC Heritage  T67  70
# 10    5.7.2023                           Wells Fargo Championship  CUT  72
# 11   5.21.2023                                   PGA Championship  T12  73
# 12    6.4.2023       the Memorial Tournament presented by Workday  T16  69
# 13   6.11.2023                                  RBC Canadian Open  T43  72
# 14   6.18.2023                                          U.S. Open  T20  72
# 15   6.25.2023                             Travelers Championship  T19  64
# 16   7.16.2023                              Genesis Scottish Open  T12  71
# 17   7.23.2023                              The Open Championship  CUT  72
# 18    8.6.2023                               Wyndham Championship  T51  68
# 19   10.1.2023                                         Ryder Cup*    1   -
#
#     R2  R3  R4 R5  TOTAL TO PAR RANK     PTS  Unnamed: 12 RANK.1 PTS.1  \
# 0   67  71  72  -  278.0     -6   99  34.833          NaN      -     -
# 1   77  71  71  -  293.0      5    -       -          NaN      -     -
# 2   76   -   -  -  151.0      9  180       -          NaN      -     -
# 3   69  71  68  -  277.0     -7  131   58.25          NaN      -     -
# 4   68  65  70  -  271.0     -9   89      93          NaN      -     -
# 5   70  80  71  -  293.0      5   97    4.08          NaN      -     -
# 6   69  68  70  -  284.0     -4   96  19.267          NaN      -     -
# 7    -   -   -  -    0.0    NaN   97  17.729          NaN      -     -
# 8   72  73  73  -  286.0     -2   88  52.886          NaN      -     -
# 9   69  74  72  -  285.0      1   90     3.3          NaN      -     -
# 10  72   -   -  -  144.0      2   99       -          NaN      -     -
# 11  67  71  69  -  280.0      E   89      68          NaN      -     -
# 12  76  70  73  -  288.0      E   88  50.925          NaN      -     -
# 13  69  70  73  -  284.0     -4   87  10.714          NaN      -     -
# 14  70  68  71  -  281.0      1   81  44.443          NaN      -     -
# 15  69  69  64  -  266.0    -14   74      43          NaN      -     -
# 16  64  65  73  -  273.0     -7   72  55.714          NaN      -     -
# 17  77   -   -  -  149.0      7   73       -          NaN      -     -
# 18  69  70  70  -  277.0     -3   78   6.629          NaN      -     -
# 19   -   -   -  -    NaN    NaN    -       -          NaN      -     -
#
#        WINNINGS Unnamed: 16
# 0    $88,305.00         NaN
# 1   $102,000.00           -
# 2             -         NaN
# 3   $355,000.00         NaN
# 4   $288,120.00         NaN
# 5    $42,600.00         NaN
# 6   $114,166.67         NaN
# 7   $113,761.91         NaN
# 8   $261,000.00           -
# 9    $41,600.00         NaN
# 10            -         NaN
# 11  $365,000.00           -
# 12  $275,500.00         NaN
# 13   $28,530.00         NaN
# 14  $200,152.00           -
# 15  $245,800.00         NaN
# 16  $151,007.14         NaN
# 17            -           -
# 18   $18,164.00         NaN
# 19            -         NaN

# %%
dataframe2['datetime'] = pd.to_datetime(dataframe2['DATE'])

# %%
dataframe2['datetime']
# Out:
# 0    2022-10-23
# 1    2022-12-04
# 2    2023-02-12
# 3    2023-02-19
# 4    2023-02-26
# 5    2023-03-05
# 6    2023-03-12
# 7    2023-03-26
# 8    2023-04-09
# 9    2023-04-16
# 10   2023-05-07
# 11   2023-05-21
# 12   2023-06-04
# 13   2023-06-11
# 14   2023-06-18
# 15   2023-06-25
# 16   2023-07-16
# 17   2023-07-23
# 18   2023-08-06
# 19   2023-10-01
# Name: datetime, dtype: datetime64[ns]

# %%
import seaborn as sns
sns.lineplot(data=dataframe2, x="datetime", y="WINNINGS")
# Out:
# <AxesSubplot:xlabel='datetime', ylabel='WINNINGS'>

# %%
dti = pd.date_range("2022-10-23", periods=52, freq="W")
len(dti)
dti
# Out:
# DatetimeIndex(['2022-10-23', '2022-10-30', '2022-11-06', '2022-11-13',
#                '2022-11-20', '2022-11-27', '2022-12-04', '2022-12-11',
#                '2022-12-18', '2022-12-25', '2023-01-01', '2023-01-08',
#                '2023-01-15', '2023-01-22', '2023-01-29', '2023-02-05',
#                '2023-02-12', '2023-02-19', '2023-02-26', '2023-03-05',
#                '2023-03-12', '2023-03-19', '2023-03-26', '2023-04-02',
#                '2023-04-09', '2023-04-16', '2023-04-23', '2023-04-30',
#                '2023-05-07', '2023-05-14', '2023-05-21', '2023-05-28',
#                '2023-06-04', '2023-06-11', '2023-06-18', '2023-06-25',
#                '2023-07-02', '2023-07-09', '2023-07-16', '2023-07-23',
#                '2023-07-30', '2023-08-06', '2023-08-13', '2023-08-20',
#                '2023-08-27', '2023-09-03', '2023-09-10', '2023-09-17',
#                '2023-09-24', '2023-10-01', '2023-10-08', '2023-10-15'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
rng = np.random.default_rng()
d = rng.poisson(mu, len(dti))
df = pd.DataFrame(data=d, index = dti)
df
# Out:
#               0
# 2022-10-23  293
# 2022-10-30  271
# 2022-11-06  291
# 2022-11-13  290
# 2022-11-20  317
# 2022-11-27  320
# 2022-12-04  294
# 2022-12-11  287
# 2022-12-18  309
# 2022-12-25  296
# 2023-01-01  319
# 2023-01-08  288
# 2023-01-15  318
# 2023-01-22  310
# 2023-01-29  297
# 2023-02-05  304
# 2023-02-12  312
# 2023-02-19  277
# 2023-02-26  318
# 2023-03-05  302
# 2023-03-12  321
# 2023-03-19  311
# 2023-03-26  284
# 2023-04-02  329
# 2023-04-09  307
# 2023-04-16  323
# 2023-04-23  295
# 2023-04-30  295
# 2023-05-07  298
# 2023-05-14  308
# 2023-05-21  306
# 2023-05-28  301
# 2023-06-04  295
# 2023-06-11  310
# 2023-06-18  304
# 2023-06-25  277
# 2023-07-02  301
# 2023-07-09  275
# 2023-07-16  314
# 2023-07-23  294
# 2023-07-30  307
# 2023-08-06  290
# 2023-08-13  323
# 2023-08-20  294
# 2023-08-27  331
# 2023-09-03  280
# 2023-09-10  301
# 2023-09-17  308
# 2023-09-24  279
# 2023-10-01  255
# 2023-10-08  284
# 2023-10-15  293

# %%
d = rng.normal(mu,sigma,len(dti))
df = pd.DataFrame(data=d, index = dti)
df
# Out:
#                      0
# 2022-10-23  281.329488
# 2022-10-30  302.037104
# 2022-11-06  301.625249
# 2022-11-13  301.774660
# 2022-11-20  302.467253
# 2022-11-27  306.576191
# 2022-12-04  284.050222
# 2022-12-11  309.024664
# 2022-12-18  327.245385
# 2022-12-25  302.778041
# 2023-01-01  307.349662
# 2023-01-08  305.616138
# 2023-01-15  298.207036
# 2023-01-22  300.295499
# 2023-01-29  295.564371
# 2023-02-05  315.036356
# 2023-02-12  298.947595
# 2023-02-19  297.543654
# 2023-02-26  305.375958
# 2023-03-05  304.670283
# 2023-03-12  300.201040
# 2023-03-19  334.653388
# 2023-03-26  303.765576
# 2023-04-02  316.586610
# 2023-04-09  299.669689
# 2023-04-16  301.951221
# 2023-04-23  294.679180
# 2023-04-30  303.529284
# 2023-05-07  303.687298
# 2023-05-14  304.079709
# 2023-05-21  298.223749
# 2023-05-28  296.469115
# 2023-06-04  290.522684
# 2023-06-11  298.777924
# 2023-06-18  311.900578
# 2023-06-25  300.785713
# 2023-07-02  287.277038
# 2023-07-09  308.924983
# 2023-07-16  299.497813
# 2023-07-23  306.326842
# 2023-07-30  297.939934
# 2023-08-06  307.311411
# 2023-08-13  301.546049
# 2023-08-20  295.029728
# 2023-08-27  298.246053
# 2023-09-03  303.964484
# 2023-09-10  297.887005
# 2023-09-17  287.818897
# 2023-09-24  307.233728
# 2023-10-01  277.193100
# 2023-10-08  289.692228
# 2023-10-15  305.619772

# %%
def f(x):
  A = 1.0 / np.sqrt(2.0 * np.pi)
  B = np.exp(-(x**2) / 2.0)
  return A * B

# %%
f(0.0)
# Out:
# 0.3989422804014327

# %%
f(3.0)
# Out:
# 0.0044318484119380075

# %%
f(300.0)
# Out:
# 0.0

# %%
# Range of x values for plotting.
x = np.linspace(-5.0, 5.0, 1001)

# Create empty plot.
fig, ax = plt.subplots(figsize=(12, 4))

# Plot f(x).
ax.plot(x, f(x));

# %%
# Range of x values for plotting.
x = np.linspace(250.0, 350.0,350)
y=  np.random.normal(300,20,350)

# Create empty plot.
fig, ax = plt.subplots(figsize=(12, 4))

# Plot f(x).
ax.hist(x)

# Plot histogram of randomly generated normal values from above.
ax.plot(x, y)

plt.show()

# %%
import numpy as np
rng.integers(10,25)
# Out:
# 12

# %%
rng.integers(100, size=10)
# Out:
# array([36, 34, 31, 79, 71, 43, 78, 16, 39, 88], dtype=int64)

# %%
rng.integers(50,100, size=10)
# Out:
# array([59, 76, 66, 97, 83, 62, 55, 95, 63, 57], dtype=int64)

# %%
rng.integers(100, size=(2,4))
# Out:
# array([[66, 96, 21, 41],
#        [ 7,  1, 10, 68]], dtype=int64)

# %%
rng.random()
# Out:
# 0.4103262006036871

# %%
rng.random(5)
# Out:
# array([0.61721151, 0.74397391, 0.45587879, 0.15700333, 0.24194159])

# %%
rng.random((5,4))
# Out:
# array([[0.86534124, 0.04304185, 0.19403164, 0.01456731],
#        [0.12639288, 0.49849088, 0.28773958, 0.67330209],
#        [0.7059753 , 0.36692481, 0.51291943, 0.22538232],
#        [0.91671535, 0.24947184, 0.33159379, 0.8645576 ],
#        [0.1627345 , 0.66178994, 0.33977391, 0.99681767]])

# %%
x = rng.random(1000000)
x
# Out:
# array([0.63263552, 0.79638273, 0.19873593, ..., 0.01211366, 0.5029628 ,
#        0.41393528])

# %%
import matplotlib.pyplot as plt
plt.hist(x)
plt.show()

# %%
rng = np.random.default_rng(seed=43)
x = rng.random()
print(x)
# Out:
# 0.6522992627009107

# %%
rng = np.random.default_rng(seed=44)
x = rng.integers(10)
print(x)
# Out:
# 6

# %%
rng = np.random.default_rng(seed=43)
x = rng.random((2,4))
print(x)
# Out:
# [[0.65229926 0.04377532 0.02002959 0.83921258]
#  [0.58714305 0.22470523 0.75179227 0.2636922 ]]

# %%
rng = np.random.default_rng(seed=43)
x = rng.integers(50,100,size=(3,3))
print(x)
# Out:
# [[75 82 70]
#  [52 78 51]
#  [63 91 73]]
